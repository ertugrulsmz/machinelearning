# %% [markdown]
# # Siamese network

# %% [markdown]
# ## Imports

# %%
try:
# %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFont, ImageDraw
import random

# %% [markdown]
# ## Prepare the Dataset

# %%
def create_pairs(x, digit_indices):
    '''Positive and negative pair creation.
    Alternates between positive and negative pairs.
    '''
    pairs = []
    labels = []
    n = min([len(digit_indices[d]) for d in range(10)]) - 1
    
    for d in range(10):
        for i in range(n):
            z1, z2 = digit_indices[d][i], digit_indices[d][i + 1]
            pairs += [[x[z1], x[z2]]]
            inc = random.randrange(1, 10)
            dn = (d + inc) % 10
            z1, z2 = digit_indices[d][i], digit_indices[dn][i]
            pairs += [[x[z1], x[z2]]]
            labels += [1, 0]
            
    return np.array(pairs), np.array(labels)


def create_pairs_on_set(images, labels):
    
    digit_indices = [np.where(labels == i)[0] for i in range(10)]
    pairs, y = create_pairs(images, digit_indices)
    y = y.astype('float32')
    
    return pairs, y


def show_image(image):
    plt.figure()
    plt.imshow(image)
    plt.colorbar()
    plt.grid(False)
    plt.show()

# %%
# load the dataset
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# prepare train and test sets
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

# normalize values
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
digit_indices = [np.where(train_labels == i)[0] for i in range(10)]
digit_indices
# Out:
# [array([    1,     2,     4, ..., 59974, 59985, 59998]),
#  array([   16,    21,    38, ..., 59989, 59991, 59996]),
#  array([    5,     7,    27, ..., 59977, 59981, 59993]),
#  array([    3,    20,    25, ..., 59971, 59980, 59997]),
#  array([   19,    22,    24, ..., 59984, 59986, 59990]),
#  array([    8,     9,    12, ..., 59983, 59995, 59999]),
#  array([   18,    32,    33, ..., 59973, 59987, 59988]),
#  array([    6,    14,    41, ..., 59951, 59979, 59992]),
#  array([   23,    35,    57, ..., 59962, 59967, 59994]),
#  array([    0,    11,    15, ..., 59932, 59970, 59978])]

# %%
# normalize values
train_images = train_images / 255.0
test_images = test_images / 255.0

# create pairs on train and test sets
tr_pairs, tr_y = create_pairs_on_set(train_images, train_labels)
ts_pairs, ts_y = create_pairs_on_set(test_images, test_labels)

# %%
tr_pairs.shape
# Out:
# (119980, 2, 28, 28)

# %%
tr_pairs[0][0].shape, tr_pairs[0][1].shape
# Out:
# ((28, 28), (28, 28))

# %% [markdown]
# You can see a sample pair of images below.

# %%
# array index
this_pair = 1

# show images at this index
show_image(ts_pairs[this_pair][0])
show_image(ts_pairs[this_pair][1])

# print the label for this pair
print(ts_y[this_pair])
# Out:
# 0.0

# %% [markdown]
# ## Build the Model
#
# Next, you'll define some utilities for building our model.

# %%
def initialize_base_network():
    input = Input(shape=(28,28,), name="base_input")
    x = Flatten(name="flatten_input")(input)
    x = Dense(128, activation='relu', name="first_base_dense")(x)
    x = Dropout(0.1, name="first_dropout")(x)
    x = Dense(128, activation='relu', name="second_base_dense")(x)
    x = Dropout(0.1, name="second_dropout")(x)
    x = Dense(128, activation='relu', name="third_base_dense")(x)

    return Model(inputs=input, outputs=x)

# %% [markdown]
# Let's see how our base network looks. This is where the two inputs will pass through to generate an output vector.

# %%
base_network = initialize_base_network()
plot_model(base_network, show_shapes=True, show_layer_names=True, to_file='base-model.png')

# %% [markdown]
# ### Siamese multiple output from base network

# %%
def euclidean_distance(vects): # none,1
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True) #keep dims make it (x,1) normally sum reduces dimension
    return K.sqrt(K.maximum(sum_square, K.epsilon()))


def eucl_dist_output_shape(shapes): #validate none,1 
    print("shapes : ",shapes)
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
# create the left input and point to the base network
input_a = Input(shape=(28,28,), name="left_input")
vect_output_a = base_network(input_a)

# create the right input and point to the base network
input_b = Input(shape=(28,28,), name="right_input")
vect_output_b = base_network(input_b)

# measure the similarity of the two vector outputs
# [vect_output_a, vect_output_b] just like that we are going to compile model [x[:,0],x[:,1]]
output = Lambda(euclidean_distance, name="output_layer", output_shape=eucl_dist_output_shape)([vect_output_a, vect_output_b])

# specify the inputs and output of the model
model = Model([input_a, input_b], output)

# plot model graph
plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')

# %% [markdown]
# ## Train the Model
#
# You can now define the custom loss for our network and start training.

# %%
def contrastive_loss_with_margin(margin):
    def contrastive_loss(y_true, y_pred):
       
        square_pred = K.square(y_pred)
        margin_square = K.square(K.maximum(margin - y_pred, 0))
        return K.mean(y_true * square_pred + (1 - y_true) * margin_square)
    return contrastive_loss

# %%
# it works like reverse accuracy due to loss function we use
rms = RMSprop()
model.compile(loss=contrastive_loss_with_margin(margin=1), 
              optimizer=rms)

history = model.fit([tr_pairs[:,0], tr_pairs[:,1]], tr_y, epochs=20, 
                    batch_size=128, validation_data=([ts_pairs[:,0], ts_pairs[:,1]], ts_y))
# Out:
# Train on 119980 samples, validate on 19980 samples
# Epoch 1/20
# 119980/119980 [==============================] - 9s 77us/sample - loss: 0.1163 - val_loss: 0.0981
# Epoch 2/20
# 119980/119980 [==============================] - 8s 67us/sample - loss: 0.0916 - val_loss: 0.0859
# Epoch 3/20
# 119980/119980 [==============================] - 8s 67us/sample - loss: 0.0820 - val_loss: 0.0816
# Epoch 4/20
# 119980/119980 [==============================] - 8s 67us/sample - loss: 0.0756 - val_loss: 0.0758
# Epoch 5/20
# 119980/119980 [==============================] - 8s 67us/sample - loss: 0.0716 - val_loss: 0.0761
# Epoch 6/20
# 119980/119980 [==============================] - 8s 67us/sample - loss: 0.0683 - val_loss: 0.0704
# Epoch 7/20
# 119980/119980 [==============================] - 8s 67us/sample - loss: 0.0662 - val_loss: 0.0723
# Epoch 8/20
# 119980/119980 [==============================] - 8s 66us/sample - loss: 0.0646 - val_loss: 0.0702
# Epoch 9/20
# ...

# %% [markdown]
# # Model with TensorFlow Data

# %%
base_network = initialize_base_network()

input_ = Input(shape=(2,28,28,), name="left_input")
input_a, input_b = Lambda(lambda x : (x[:,0],x[:,1]))(input_)


# create the left input and point to the base network
vect_output_a = base_network(input_a)

# create the right input and point to the base network
vect_output_b = base_network(input_b)

# measure the similarity of the two vector outputs
# [vect_output_a, vect_output_b] just like that we are going to compile model [x[:,0],x[:,1]]
output = Lambda(euclidean_distance, name="output_layer", output_shape=eucl_dist_output_shape)([vect_output_a, vect_output_b])

# specify the inputs and output of the model
model = Model(input_, output)

# plot model graph
plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')

# %%
""" was using exactly same network as it was with numpy
tr_input = tf.data.Dataset.from_tensor_slices(((tr_pairs[:,0], tr_pairs[:,1]),tr_y))
tr_input = tr_input.batch(128)

ts_input = tf.data.Dataset.from_tensor_slices(((ts_pairs[:,0], ts_pairs[:,1]),ts_y))
ts_input = ts_input.batch(128)
"""
tr_input = tf.data.Dataset.from_tensor_slices((tr_pairs,tr_y))
tr_input = tr_input.shuffle(119980).batch(128)

ts_input = tf.data.Dataset.from_tensor_slices((ts_pairs,ts_y))
ts_input = ts_input.batch(128)

# %%
# it works like reverse accuracy due to loss function we use
rms = RMSprop()
model.compile(loss=contrastive_loss_with_margin(margin=1), 
              optimizer=rms)

history = model.fit(tr_input, epochs=20, 
                     validation_data=(ts_input))
# Out:
# Train for 938 steps, validate for 157 steps
# Epoch 1/20
# 938/938 [==============================] - 15s 16ms/step - loss: 0.1041 - val_loss: 0.0904
# Epoch 2/20
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0941 - val_loss: 0.0860
# Epoch 3/20
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0910 - val_loss: 0.0838
# Epoch 4/20
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0885 - val_loss: 0.0834
# Epoch 5/20
# 938/938 [==============================] - 10s 10ms/step - loss: 0.0866 - val_loss: 0.0809
# Epoch 6/20
# 938/938 [==============================] - 12s 13ms/step - loss: 0.0853 - val_loss: 0.0821
# Epoch 7/20
# 938/938 [==============================] - 10s 10ms/step - loss: 0.0843 - val_loss: 0.0792
# Epoch 8/20
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0835 - val_loss: 0.0782
# Epoch 9/20
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0825 - val_loss: 0.0782
# ...

# %% [markdown]
# ## Model Evaluation
#
# As usual, you can evaluate our model by computing the accuracy and observing the metrics during training.
# it works like reverse accuracy due to loss function we use

# %%
def compute_accuracy(y_true, y_pred):
    pred = y_pred.flatten() < 0.5 # or ravel
    return np.mean(pred == y_true)

# %%
loss = model.evaluate(x=[ts_pairs[:,0],ts_pairs[:,1]], y=ts_y)

y_pred_train = model.predict([tr_pairs[:,0], tr_pairs[:,1]])
train_accuracy = compute_accuracy(tr_y, y_pred_train)

y_pred_test = model.predict([ts_pairs[:,0], ts_pairs[:,1]])
test_accuracy = compute_accuracy(ts_y, y_pred_test)

print("Loss = {}, Train Accuracy = {} Test Accuracy = {}".format(loss, train_accuracy, test_accuracy))

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)


plot_metrics(metric_name='loss', title="Loss", ylim=0.2)

# %%
# Matplotlib config
def visualize_images():
    plt.rc('image', cmap='gray_r')
    plt.rc('grid', linewidth=0)
    plt.rc('xtick', top=False, bottom=False, labelsize='large')
    plt.rc('ytick', left=False, right=False, labelsize='large')
    plt.rc('axes', facecolor='F8F8F8', titlesize="large", edgecolor='white')
    plt.rc('text', color='a8151a')
    plt.rc('figure', facecolor='F0F0F0')# Matplotlib fonts


# utility to display a row of digits with their predictions
def display_images(left, right, predictions, labels, title, n):
    plt.figure(figsize=(17,3))
    plt.title(title)
    plt.yticks([])
    plt.xticks([])
    plt.grid(None)
    left = np.reshape(left, [n, 28, 28])
    left = np.swapaxes(left, 0, 1)
    left = np.reshape(left, [28, 28*n])
    plt.imshow(left)
    plt.figure(figsize=(17,3))
    plt.yticks([])
    plt.xticks([28*x+14 for x in range(n)], predictions)
    for i,t in enumerate(plt.gca().xaxis.get_ticklabels()):
        if predictions[i] > 0.5: t.set_color('red') # bad predictions in red
    plt.grid(None)
    right = np.reshape(right, [n, 28, 28])
    right = np.swapaxes(right, 0, 1)
    right = np.reshape(right, [28, 28*n])
    plt.imshow(right)

# %% [markdown]
# You can see sample results for 10 pairs of items below.

# %%
y_pred_train = np.squeeze(y_pred_train)
indexes = np.random.choice(len(y_pred_train), size=10)
display_images(tr_pairs[:, 0][indexes], tr_pairs[:, 1][indexes], y_pred_train[indexes], tr_y[indexes], "clothes and their dissimilarity", 10)
