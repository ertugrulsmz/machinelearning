# %%
import pandas as pd
import numpy as np

a = {"a":[1,np.nan,2,3,np.nan,4,np.nan],
    "b":[9,np.nan,np.nan,7,np.nan,9,np.nan],
    "c":[2,np.nan,np.nan,np.nan,4,7,8]}

df = pd.DataFrame(a)

df
# Out:
#      a    b    c
# 0  1.0  9.0  2.0
# 1  NaN  NaN  NaN
# 2  2.0  NaN  NaN
# 3  3.0  7.0  NaN
# 4  NaN  NaN  4.0
# 5  4.0  9.0  7.0
# 6  NaN  NaN  8.0

# %%
# !pip install --quiet  missingno

# %%
import missingno as msno
msno.bar(df)

# %%
msno.matrix(df)

# %%
msno.heatmap(df) # how nullness is correlated
