# %%
import pandas as pd
import numpy as np 

df = pd.read_csv("WHO COVID-19.csv")
df
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0    United States of America         Americas                  22229803
# 1                       India  South-East Asia                  10479179
# 2                      Brazil         Americas                   8105790
# 3          Russian Federation           Europe                   3448203
# 4          The United Kingdom           Europe                   3118522
# ..                        ...              ...                       ...
# 144                    Guyana         Americas                      6574
# 145                   Mayotte           Africa                      6255
# 146                Martinique         Americas                      6227
# 147                     Aruba         Americas                      6042
# 148                   Iceland           Europe                      5898
#
#      Cases - cumulative per 1 million  Cases - Last 7 days  \
# ...

# %%
df_Europe = df[df["WHO Region"] == "Europe"]
df_Europe
# Out:
#                        Name WHO Region  Cases - cumulative total  \
# 3        Russian Federation     Europe                   3448203
# 4        The United Kingdom     Europe                   3118522
# 5                    France     Europe                   2740656
# 6                     Italy     Europe                   2289021
# 7                     Spain     Europe                   2111782
# 8                   Germany     Europe                   1933826
# 12                   Turkey     Europe                   1522138
# 13                   Poland     Europe                   1390385
# 16                  Ukraine     Europe                   1124430
# 18              Netherlands     Europe                    878263
# 19                  Czechia     Europe                    844799
# 21                  Romania     Europe                    673271
# 22                  Belgium     Europe                    665223
# ...

# %%
X = df_Europe.iloc[:, 2:10]
X
# Out:
#      Cases - cumulative total  Cases - cumulative per 1 million  \
# 3                     3448203                          23628.44
# 4                     3118522                          45937.62
# 5                     2740656                          41987.26
# 6                     2289021                          37858.95
# 7                     2111782                          45167.19
# 8                     1933826                          23081.11
# 12                    1522138                          18047.84
# 13                    1390385                          36737.37
# 16                    1124430                          25710.80
# 18                     878263                          51255.88
# 19                     844799                          78886.96
# 21                     673271                          34997.50
# 22                     665223                          57398.16
# 28                     493501                          57015.66
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled = scaler.fit_transform(X)

df_scaled = pd.DataFrame(scaled, columns = X.columns, index= df_Europe["Name"])
df_scaled
# Out:
#                         Cases - cumulative total  \
# Name
# Russian Federation                      1.000000
# The United Kingdom                      0.904227
# France                                  0.794455
# Italy                                   0.663254
# Spain                                   0.611766
# Germany                                 0.560069
# Turkey                                  0.440472
# Poland                                  0.402198
# Ukraine                                 0.324937
# Netherlands                             0.253425
# Czechia                                 0.243703
# Romania                                 0.193874
# Belgium                                 0.191536
# Israel                                  0.141650
# Sweden                                  0.140479
# Portugal                                0.140428
# Switzerland                             0.138336
# Austria                                 0.108978
# ...

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

plt.figure(dpi=150)

linkage_matrix = linkage(df_scaled, method = "ward", metric = "euclidean")

dendrogram(linkage_matrix, labels = df_scaled.index.to_list())
plt.show()
